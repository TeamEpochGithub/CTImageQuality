# %%
import pydicom
from pydicom.pixel_data_handlers.util import apply_voi_lut
import matplotlib.pyplot as plt
import  numpy as np

# %%
full_dose_file = r"C:\EpochProjects\CTImageQuality\data\QD_3mm_sharp\quarter_3mm_sharp\L067\quarter_3mm_sharp\L067_QD_3_SHARP_1.CT.0003.0001.2016.01.21.18.12.01.921560.405032914.IMA"
# low_dose_file = r"C:\EpochProjects\CTImageQuality\data\L067_QD_1_1.CT.0003.0001.2015.12.22.18.10.55.420810.358276339.IMA"
fds = pydicom.dcmread(full_dose_file)
# lds = pydicom.dcmread(low_dose_file)

plt.imshow(fds.pixel_array, cmap='gray')  # set the color map to bone
plt.show()

# %%
plt.imshow(lds.pixel_array, cmap=plt.cm.bone)
plt.show()

# %%
# Out:
# array([[1973, 1901, 1308, ..., 1706, 1984, 1561],
#        [1597, 1342, 1176, ..., 1729, 1305, 1257],
#        [1176, 1386, 1387, ..., 1176, 1376, 1355],
#        ...,
#        [1638, 1555, 1523, ..., 1176, 1296, 1339],
#        [1637, 1363, 1508, ..., 1463, 1176, 1521],
#        [1223, 1176, 1632, ..., 1191, 1497, 1176]], dtype=uint16)
